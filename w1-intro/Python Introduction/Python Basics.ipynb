# %% [markdown]
# ## Python Installation

# %% [markdown]
# https://www.python.org/downloads/ to download python
#
# #### Jupyter notebook
#
# Go to terminal and enter jupyter notebook
#
# #### Google colab
#
# https://colab.research.google.com/?utm_source=scs-index to open google colab

# %% [markdown]
# ## Keywords

# %% [markdown]
# Keywords are the reserved words in Python.

# %% [markdown]
# We cannot use a keyword as a variable name, function name or any other identifier.

# %% [markdown]
# They are used to define the syntax and structure of the Python language.

# %% [markdown]
# Keywords are case sensitive.

# %% [markdown]
# Examples : False, True, None, and, as, assert, async, await, break, class, continue, def, del, elif, else, except, finally etc.

# %% [markdown]
# ## Identifiers

# %% [markdown]
# An identifier is a name given to entities like class, functions, variables, etc. It helps to differentiate one entity from another.

# %% [markdown]
# Identifiers can be a combination of letters in lowercase (a to z) or uppercase (A to Z) or digits (0 to 9) or an underscore(_).

# %% [markdown]
# An identifier cannot start with a digit.

# %% [markdown]
# Keywords cannot be used as identifiers.

# %% [markdown]
# Python is a case-sensitive language. So, Variable and variable are two different identifiers.

# %% [markdown]
# ## Statements

# %% [markdown]
# Instructions that a Python interpreter can execute are called statements.

# %% [markdown]
# For example, a = 1 is an assignment statement. if statement, for statement, while statement, etc. are also the examples of statements.

# %% [markdown]
# #### Multiline statements

# %%
a = 1 + 2 + 3 + \
    4 + 5 + 6 + \
    7 + 8 + 9

# %%
print(a)
# Out:
# 45

# %%
a = (1 + 2 + 3 +
    4 + 5 + 6 +
    7 + 8 + 9)

# %%
print(a)
# Out:
# 45

# %% [markdown]
# We can also put multiple statements in a single line using semicolons.

# %%
a = 1; b = 2; c = 3

# %% [markdown]
# ## Indentation

# %% [markdown]
# A code block(body of a function, loop, etc.) starts with indentation.

# %% [markdown]
# The amount of indentation is up to you, but it must be consistent throughout that block.

# %% [markdown]
# Generally, four whitespaces or a tab are used for indentation.

# %%
for i in range(1,11):
    print(i)
    if i == 5:
        break
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ## Comments

# %% [markdown]
# Using comments in programs makes our code more understandable.

# %% [markdown]
# Other than that, comments can also be used to ignore some code while testing other blocks of code. This offers a simple way to prevent the execution of some lines or write a quick pseudo-code for the program.

# %% [markdown]
# In Python, we use the hash symbol(#) to start writing a comment.

# %%
#This is a comment
#print Hello
print('Hello')
# Out:
# Hello

# %% [markdown]
# ## Variables

# %% [markdown]
# variable is a container that holds data that can be changed later in the program.

# %%
number = 10
number = 1.1

# %%
website = "apple.com"

# %% [markdown]
# #### Assigning multiple values to multiple variables

# %%
a, b, c = 5, 3.2, "Hello"
print (a)
print (b)
print (c)
# Out:
# 5
# 3.2
# Hello

# %% [markdown]
# ## Basic Data types

# %% [markdown]
# Every value in Python has a datatype.

# %% [markdown]
#  Since everything is an object in Python programming, data types are actually classes and variables are instance (object) of these classes.

# %% [markdown]
# #### Python Numbers

# %% [markdown]
# Integers, floating point numbers and complex numbers fall under Python numbers category.

# %%
a = 5
print(a, "is of type", type(a))

a = 2.0
print(a, "is of type", type(a))

a = 1+2j
print(a, "is of type", type(a))
# Out:
# 5 is of type <class 'int'>
# 2.0 is of type <class 'float'>
# (1+2j) is of type <class 'complex'>

# %% [markdown]
# #### Characters and strings

# %% [markdown]
# character literal is a single character surrounded by single or double quotes.

# %% [markdown]
# A string literal is a sequence of characters surrounded by quotes.

# %%
char = "C"
strings = "This is Python"
print(char)
print(strings)
# Out:
# C
# This is Python

# %% [markdown]
# #### Boolean

# %%
x = (1 == True)
y = (1 == False)
a = True + 4
b = False + 10

print(x)
print(y)
print(a)
print(b)
# Out:
# True
# False
# 5
# 10

# %% [markdown]
# ## Type conversion

# %% [markdown]
# Type Conversion is the conversion of object from one data type to another data type.

# %%
num_int = 123
num_str = "456"
num_str=int(num_str)

# %%
print(type(num_str))
# Out:
# <class 'int'>

# %% [markdown]
# ## Python Input & Output

# %% [markdown]
# #### User Input

# %%
num = int(input('Enter a number: '))
# Out:
# Enter a number: 6

# %%
type(num)
# Out:
# int

# %% [markdown]
# #### Output

# %% [markdown]
# ##### Print()

# %% [markdown]
# We use the print() function to output data to the standard output device.

# %%
print('This sentence is output to the screen')
# Out:
# This sentence is output to the screen

# %%
a = 5
print('The value of a is', a)
# Out:
# The value of a is 5

# %% [markdown]
# ##### .format()

# %%
x = 5
y = 10
print('The value of x is {} and y is {}'.format(x,y))
# Out:
# The value of x is 5 and y is 10

# %% [markdown]
# ## Operators

# %% [markdown]
# Operators are special symbols in Python that carry out arithmetic or logical computation. The value that the operator operates on is called the operand.

# %% [markdown]
# ### Arithmetic operators

# %%
x = 15
y = 4

print('x + y =',x+y)

print('x - y =',x-y)

print('x * y =',x*y)

print('x / y =',x/y)

print('x % y =',x%y)

print('x // y =',x//y)

print('x ** y =',x**y)
# Out:
# x + y = 19
# x - y = 11
# x * y = 60
# x / y = 3.75
# x % y = 3
# x // y = 3
# x ** y = 50625

# %% [markdown]
# ### Comparison operators

# %% [markdown]
# Comparison operators are used to compare values. It returns either True or False.

# %%
x = 10
y = 12

print('x > y is',x>y)

print('x < y is',x<y)

print('x == y is',x==y)

print('x != y is',x!=y)

print('x >= y is',x>=y)

print('x <= y is',x<=y)
# Out:
# x > y is False
# x < y is True
# x == y is False
# x != y is True
# x >= y is False
# x <= y is True

# %% [markdown]
# ### Logical operators

# %% [markdown]
# Logical operators are the and, or, not operators.

# %%
x = True
y = False

print('x and y is',x and y)

print('x or y is',x or y)

print('not x is',not x)
# Out:
# x and y is False
# x or y is True
# not x is False

# %% [markdown]
# ### Bitwise operators

# %% [markdown]
# Bitwise operators act on binary numbers. They operate bit by bit.

# %%
x = 10
y = 4

print('x & y is',x&y)

print('x | y is',x|y)

print('~x ',~x)

print('x ^ y is',x^y)

print('x >> 2 is',x>>2)

print('x << 2 is',x<<2)
# Out:
# x & y is 0
# x | y is 14
# ~x  -11
# x ^ y is 14
# x >> 2 is 2
# x << 2 is 40

# %% [markdown]
# ### Assignment operators

# %% [markdown]
# Assignment operators are used in Python to assign values to variables.

# %%
a=10

a+=2
print(a)

a-=2
print(a)

a*=2
print(a)

a/=2
print(a)
# Out:
# 12
# 10
# 20
# 10.0

# %% [markdown]
# ### Special operators

# %% [markdown]
# #### Identity operators

# %% [markdown]
# 'is' and 'is not' are the identity operators in Python

# %%
x1 = 5
y1 = 5
x2 = 'Hello'
y2 = 'Hello'

print(x1 is not y1)

print(x2 is y2)
# Out:
# False
# True

# %% [markdown]
# #### Membership operators

# %% [markdown]
# 'in' and 'not in' are the membership operators in Python.

# %%
x = 'Hello world'
y = {1:'a',2:'b'}

print('H' in x)

print(1 in y)
# Out:
# True
# True

# %% [markdown]
# ## Flow control

# %% [markdown]
# ### If-else

# %%
num = 3

if num >= 0:
    print("Positive or Zero")
else:
    print("Negative number")
# Out:
# Positive or Zero

# %% [markdown]
# ### If-elif-else

# %%
num = 3.4

if num > 0:
    print("Positive number")
elif num == 0:
    print("Zero")
else:
    print("Negative number")
# Out:
# Positive number

# %% [markdown]
# ### Nested if

# %%
num=5
if num >= 0:
    if num == 0:
        print("Zero")
    else:
        print("Positive number")
else:
    print("Negative number")
# Out:
# Positive number

# %% [markdown]
# ### For loop

# %%
numbers = [6, 5, 3, 8]

sum = 0

for val in numbers:
    print(val)
# Out:
# 6
# 5
# 3
# 8

# %%
for i in range(0,5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ### While loop

# %%
sum=0
i=0
n=5
while i <= n:
    sum = sum + i
    i = i+1 
print(sum)
# Out:
# 15

# %% [markdown]
# ### Break

# %% [markdown]
# The break statement terminates the loop containing it. Control of the program flows to the statement immediately after the body of the loop.

# %%
for val in "string":
    if val == "i":
        break
    print(val)
# Out:
# s
# t
# r

# %% [markdown]
# ### Continue

# %% [markdown]
# The continue statement is used to skip the rest of the code inside a loop for the current iteration only. Loop does not terminate but continues on with the next iteration.

# %%
for val in "string":
    if val == "i":
        continue
    print(val)
# Out:
# s
# t
# r
# n
# g

# %%
for j in range(4):
  print(j)
  continue
# Out:
# 0
# 1
# 2
# 3
