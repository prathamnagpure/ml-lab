# %% [markdown]
# # Pandas
#
# ##### Pandas is one of the important tools in Machine Learning.
# ##### When working with tabular data, such as data stored in spreadsheets or databases, pandas is the right tool for you.
# ##### pandas will help you to explore, clean, and process your data.
# ##### In pandas, a data table is called a DataFrame.
# ##### You can think of pandas as an extremely powerful version of Excel, with a lot more features.

# %%
import pandas as pd
import numpy as np
from numpy.random import randn

# %% [markdown]
# ### DataFrames
#
# ##### We can think of a DataFrame as a bunch of Series objects put together to share the same index.
# ##### Two-dimensional, size-mutable, potentially heterogeneous tabular data.

# %%
df = pd.DataFrame(randn(5,4),index='A B C D E'.split(),columns='W X Y Z'.split())
df
# Out:
#           W         X         Y         Z
# A -0.715736  0.216925  0.189175  0.346535
# B  0.137751  0.211191  0.010864  1.281956
# C  0.747632 -0.188069 -0.404232  0.766014
# D  0.228245 -0.257900 -0.561054 -0.776097
# E  0.382309  0.684328 -0.749057 -0.375627

# %% [markdown]
# ### Indexing

# %%
df['X']
# Out:
# A    0.216925
# B    0.211191
# C   -0.188069
# D   -0.257900
# E    0.684328
# Name: X, dtype: float64

# %%
df[['W','Y']]
# Out:
#           W         Y
# A -0.715736  0.189175
# B  0.137751  0.010864
# C  0.747632 -0.404232
# D  0.228245 -0.561054
# E  0.382309 -0.749057

# %%
df.Y
# Out:
# A    0.189175
# B    0.010864
# C   -0.404232
# D   -0.561054
# E   -0.749057
# Name: Y, dtype: float64

# %% [markdown]
# ### Creating a new column:

# %%
df['new'] = df['W'] + df['Y']

# %%
df
# Out:
#           W         X         Y         Z       new
# A -0.715736  0.216925  0.189175  0.346535 -0.526562
# B  0.137751  0.211191  0.010864  1.281956  0.148615
# C  0.747632 -0.188069 -0.404232  0.766014  0.343400
# D  0.228245 -0.257900 -0.561054 -0.776097 -0.332809
# E  0.382309  0.684328 -0.749057 -0.375627 -0.366748

# %% [markdown]
# ### Removing Columns

# %%
df.drop('new',axis=1)
# Out:
#           W         X         Y         Z
# A -0.715736  0.216925  0.189175  0.346535
# B  0.137751  0.211191  0.010864  1.281956
# C  0.747632 -0.188069 -0.404232  0.766014
# D  0.228245 -0.257900 -0.561054 -0.776097
# E  0.382309  0.684328 -0.749057 -0.375627

# %%
# Not inplace unless specified!
df
# Out:
#           W         X         Y         Z       new
# A -0.715736  0.216925  0.189175  0.346535 -0.526562
# B  0.137751  0.211191  0.010864  1.281956  0.148615
# C  0.747632 -0.188069 -0.404232  0.766014  0.343400
# D  0.228245 -0.257900 -0.561054 -0.776097 -0.332809
# E  0.382309  0.684328 -0.749057 -0.375627 -0.366748

# %%
df.drop('new',axis=1,inplace=True)

# %%
df
# Out:
#           W         X         Y         Z
# A -0.715736  0.216925  0.189175  0.346535
# B  0.137751  0.211191  0.010864  1.281956
# C  0.747632 -0.188069 -0.404232  0.766014
# D  0.228245 -0.257900 -0.561054 -0.776097
# E  0.382309  0.684328 -0.749057 -0.375627

# %%
new_df = df.drop('Z', axis='columns')
new_df
# Out:
#           W         X         Y
# A -0.715736  0.216925  0.189175
# B  0.137751  0.211191  0.010864
# C  0.747632 -0.188069 -0.404232
# D  0.228245 -0.257900 -0.561054
# E  0.382309  0.684328 -0.749057

# %% [markdown]
# ### Removing rows

# %%
df.drop('E',axis=0)
# Out:
#           W         X         Y         Z
# A -0.715736  0.216925  0.189175  0.346535
# B  0.137751  0.211191  0.010864  1.281956
# C  0.747632 -0.188069 -0.404232  0.766014
# D  0.228245 -0.257900 -0.561054 -0.776097

# %%
new_df = df.drop('A', axis='index')
new_df
# Out:
#           W         X         Y         Z
# B  0.137751  0.211191  0.010864  1.281956
# C  0.747632 -0.188069 -0.404232  0.766014
# D  0.228245 -0.257900 -0.561054 -0.776097
# E  0.382309  0.684328 -0.749057 -0.375627

# %% [markdown]
# ### Selecting Rows

# %%
df.loc['A']
# Out:
# W   -0.715736
# X    0.216925
# Y    0.189175
# Z    0.346535
# Name: A, dtype: float64

# %% [markdown]
# Or select based on the position instead of label

# %%
df.iloc[0]
# Out:
# W   -0.715736
# X    0.216925
# Y    0.189175
# Z    0.346535
# Name: A, dtype: float64

# %% [markdown]
# ### Selecting subset of rows and columns

# %%
df.loc['B','Y']
# Out:
# 0.010864333019626842

# %%
df.loc[['A','B'],['W','Y']]
# Out:
#           W         Y
# A -0.715736  0.189175
# B  0.137751  0.010864

# %% [markdown]
# ### Conditional Selection
#
# An important feature of pandas is conditional selection using bracket notation, very similar to numpy.

# %%
df
# Out:
#           W         X         Y         Z
# A -0.715736  0.216925  0.189175  0.346535
# B  0.137751  0.211191  0.010864  1.281956
# C  0.747632 -0.188069 -0.404232  0.766014
# D  0.228245 -0.257900 -0.561054 -0.776097
# E  0.382309  0.684328 -0.749057 -0.375627

# %%
df>0
# Out:
#        W      X      Y      Z
# A  False   True   True   True
# B   True   True   True   True
# C   True  False  False   True
# D   True  False  False  False
# E   True   True  False  False

# %%
df[df>0]
# Out:
#           W         X         Y         Z
# A       NaN  0.216925  0.189175  0.346535
# B  0.137751  0.211191  0.010864  1.281956
# C  0.747632       NaN       NaN  0.766014
# D  0.228245       NaN       NaN       NaN
# E  0.382309  0.684328       NaN       NaN

# %%
df[df['W']>0]
# Out:
#           W         X         Y         Z
# B  0.137751  0.211191  0.010864  1.281956
# C  0.747632 -0.188069 -0.404232  0.766014
# D  0.228245 -0.257900 -0.561054 -0.776097
# E  0.382309  0.684328 -0.749057 -0.375627

# %%
df[df['W']>0]['Y']
# Out:
# B    0.010864
# C   -0.404232
# D   -0.561054
# E   -0.749057
# Name: Y, dtype: float64

# %%
df[df['W']>0][['Y','X']]
# Out:
#           Y         X
# B  0.010864  0.211191
# C -0.404232 -0.188069
# D -0.561054 -0.257900
# E -0.749057  0.684328

# %% [markdown]
# For two conditions you can use | and & with parenthesis:

# %%
df[(df['W']>0) & (df['Y'] > 0.5)]
# Out:
# Empty DataFrame
# Columns: [W, X, Y, Z]
# Index: []

# %% [markdown]
# ### Operations
#
# There are lots of operations with pandas that will be really useful to you, but don't fall into any distinct category. Let's show them here in this lecture:

# %%
import pandas as pd
df = pd.DataFrame({'col1':[1,2,3,4,5,6],'col2':[444,555,666,444,777,888],'col3':['abc','def','ghi','xyz','ijk','lmn']})
df
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz
# 4     5   777  ijk
# 5     6   888  lmn

# %%
df.head()
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz
# 4     5   777  ijk

# %% [markdown]
# ### Unique Values

# %%
df['col2'].unique()
# Out:
# array([444, 555, 666, 777, 888])

# %%
df['col2'].nunique()
# Out:
# 5

# %%
df['col2'].value_counts()
# Out:
# 444    2
# 555    1
# 666    1
# 777    1
# 888    1
# Name: col2, dtype: int64

# %% [markdown]
# ### Selecting Data

# %%
#Select from DataFrame using criteria from multiple columns
newdf = df[(df['col1']>2) & (df['col2']==444)]
newdf
# Out:
#    col1  col2 col3
# 3     4   444  xyz

# %% [markdown]
# ### Applying Functions

# %%
df
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz
# 4     5   777  ijk
# 5     6   888  lmn

# %%
def times_2(x):
    return x*2

# %%
df['col1'].apply(times_2)
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# 5    12
# Name: col1, dtype: int64

# %%
df['col3'].apply(len)
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# 4    3
# 5    3
# Name: col3, dtype: int64

# %%
df['col1'].sum()
# Out:
# 21

# %% [markdown]
# ### Permanently Removing a Column

# %%
del df['col1']

# %%
df
# Out:
#    col2 col3
# 0   444  abc
# 1   555  def
# 2   666  ghi
# 3   444  xyz
# 4   777  ijk
# 5   888  lmn

# %% [markdown]
# ### Get column and index names:

# %%
df.columns
# Out:
# Index(['col2', 'col3'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %% [markdown]
# ### Sorting and Ordering a DataFrame:

# %%
df
# Out:
#    col2 col3
# 0   444  abc
# 1   555  def
# 2   666  ghi
# 3   444  xyz
# 4   777  ijk
# 5   888  lmn

# %%
df.sort_values(by='col2') #inplace=False by default
# Out:
#    col2 col3
# 0   444  abc
# 3   444  xyz
# 1   555  def
# 2   666  ghi
# 4   777  ijk
# 5   888  lmn
